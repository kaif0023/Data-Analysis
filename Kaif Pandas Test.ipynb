# %%
import numpy as np
import pandas as pd

# %%
crop=pd.read_csv("C:\\Users\\md kaif\\Downloads\\apy_2.csv")

# %%
crop.head(20)
# Out:
#     Unnamed: 0      State_Name   District_Name  Crop_Year       Season  \
# 0            0       Karnataka           UDUPI       2005  Rabi
# 1            1  Madhya Pradesh         GWALIOR       2003  Whole Year
# 2            2  Andhra Pradesh        CHITTOOR       2010  Rabi
# 3            3  Andhra Pradesh         KRISHNA       2014  Rabi
# 4            4   Uttar Pradesh       SULTANPUR       2011  Rabi
# 5            5       Rajasthan         JODHPUR       2002  Whole Year
# 6            6           Assam          KAMRUP       2006  Kharif
# 7            7           Assam       SIVASAGAR       2014  Autumn
# 8            8           Bihar       JEHANABAD       2001  Whole Year
# 9            9          Odisha        NAYAGARH       2009  Winter
# 10          10           Assam       DIBRUGARH       2011  Rabi
# 11          11  Madhya Pradesh          MORENA       2008  Kharif
# 12          12  Madhya Pradesh           SIDHI       2013  Whole Year
# ...

# %%
crop.dtypes
# Out:
# Unnamed: 0         int64
# State_Name        object
# District_Name     object
# Crop_Year          int64
# Season            object
# Crop              object
# Area             float64
# Production       float64
# dtype: object

# %%
crop.isnull().sum()
# Out:
# Unnamed: 0          0
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       1148
# dtype: int64

# %%
crop.dropna(how="any",inplace=True)

# %%
crop.isnull().sum()
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
crop.drop(columns=["Unnamed: 0"],inplace=True)

# %%
crop.head()
# Out:
#        State_Name District_Name  Crop_Year       Season        Crop    Area  \
# 0       Karnataka         UDUPI       2005  Rabi         Horse-gram  1122.0
# 1  Madhya Pradesh       GWALIOR       2003  Whole Year      Brinjal   194.0
# 2  Andhra Pradesh      CHITTOOR       2010  Rabi            Sesamum   334.0
# 3  Andhra Pradesh       KRISHNA       2014  Rabi             Tomato   538.0
# 4   Uttar Pradesh     SULTANPUR       2011  Rabi          Coriander    59.0
#
#    Production
# 0       836.0
# 1         0.0
# 2       118.0
# 3      7289.0
# 4        33.0

# %%
crop["Season"].unique()
# Out:
# array(['Rabi       ', 'Whole Year ', 'Kharif     ', 'Autumn     ',
#        'Winter     ', 'Summer     '], dtype=object)

# %%
#1
crop[crop["Season"]=="Summer     "]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 2
#       1 #1
# ----> 2 crop[crop["Season"]=="Summer     "]
#
# NameError: name 'crop' is not defined

# %%
##Q.3
crop.groupby("Crop_Year")["Area"].agg(["max","min"]).head(20)
# Out:
#                  max   min
# Crop_Year
# 1997       4205800.0  1.00
# 1998        545286.0  1.00
# 1999        699894.0  1.00
# 2000        636700.0  1.00
# 2001        483246.0  1.00
# 2002        672100.0  1.00
# 2003       1020181.0  1.00
# 2004        857823.0  0.50
# 2005        464880.0  1.00
# 2006        933271.0  1.00
# 2007        448200.0  1.00
# 2008        608851.0  1.00
# 2009        967622.0  1.00
# 2010        545965.0  1.00
# 2011        482718.0  0.63
# 2012        486172.0  1.00
# 2013        711145.0  1.00
# 2014        496134.0  1.00
# 2015        278000.0  1.00

# %%
crop.groupby(["State_Name"])["Production"].agg(["max"])
# Out:
#                                       max
# State_Name
# Andaman and Nicobar Islands  7.130000e+07
# Andhra Pradesh               7.801620e+08
# Arunachal Pradesh            3.501000e+04
# Assam                        3.790100e+07
# Bihar                        7.288132e+06
# Chandigarh                   3.960000e+03
# Chhattisgarh                 8.447640e+05
# Dadra and Nagar Haveli       1.229600e+05
# Goa                          7.141000e+07
# Gujarat                      9.147000e+06
# Haryana                      2.650000e+06
# Himachal Pradesh             1.702830e+05
# Jammu and Kashmir            1.628500e+05
# Jharkhand                    5.095690e+05
# Karnataka                    1.626448e+07
# Kerala                       1.001000e+09
# Madhya Pradesh               1.205590e+06
# Maharashtra                  1.696350e+07
# Manipur                      6.799000e+04
# Meghalaya                    1.128920e+05
# Mizoram                      5.024100e+04
# ...

# %%
#10
crop["Area"].mean()
# Out:
# 12035.385977242398
